# %% [markdown]
# # <font face = "Times New Roman"><center>  Mathematical Foundations of Data Science </center> <center>Assignment 5</center> </font>
# #### <font face = "Times New Roman"> <p align="right">Trimester 1, 2023 <br><br> Chang Dong (a1807402)</p> </font>

# %% [markdown]
# **<p style="line-height: 1.5">
# <font size = 4px face = "Times New Roman">1. Consider the following augmented matrix:
# <br>
# $$\left[
# \begin{array}{ccc|c}
#   x-2&0&0&3 \\
#   0&x^2 -4&0&x+2\\
#   0&0&1&4
# \end{array}
# \right]$$
# <br>
# Determine the number of solutions to this system for all possible values of x ∈ R, giving justification.</font></p>**

# %% [markdown]
# <p style="line-height: 2">
# <font size = 4px face = "Times New Roman">
# <i>Answer:</i><br>
# <p style="line-height: 4">
# $A = \begin{bmatrix}x-2&0&0\\0&x^2 -4&0\\0&0&1\end{bmatrix},\ \ b = \begin{bmatrix}3\\x+2\\4\end{bmatrix}$
# </p>
# <br>
# <p style="line-height: 2">
# <b>1). No solution (meet either case):</b><br>
# <b>Case 1 : </b><br>
# $\ \ \ \ $   when $x-2 = 0$, so $x = 2$ $\ $,  beacause $0·x_1 \ne 3$<br>
# <b>Case 2 : </b><br>
# $\ \ \ \ $       when $x^2-4 = 0$, while $x+2 \ne 0$ , so $x = 2$ $\ $,  beacause $0·x_2 \ne x+2,$ where $ x+2\ne 0$<br>
# <b>Thus:</b><br>
# <b>$\ \ \ \ $ when $x = 2:\ $ This equation has no solution. </b><br>
# </p>
# <p style="line-height: 2">
# <b>2). Have solution (meet all condition):</b><br>
# <b>Condition 1: </b><br>
# $\ \ \ \ $    when $x-2 \ne 0$, so $x \ne 2$<br>
# <b>Condition 2</b> (meet either case): <br>
# $\ \ \ \ $     <b>Case 1</b>: when  $x^2-4 = 0$, while $x+2 = 0$ , so $x = -2$<br>
# $\ \ \ \ $     <b>Case 2</b>: or when  $x^2-4 \ne 0$, while $x+2 \ne 0$ , so $x \ne ±2$<br>
# $\ \ \ \ $     Thus, in condition 2, $x \ne 2$
#
# Thus, in all case, if $x \ne 2$, that can make this equation have solution
# </p>
# <p style="line-height: 2">
# <b>$\ \ \ \ $ when $x \ne ±2:\ $ Solution Set $\ (x_1,x_2,x_3)$ = $[\frac{3}{x-2}, \frac{1}{x-2},4]^T$,$\ $ unique solution </b><br>
# <b>$\ \ \ \ $ when  $x = -2:\ $ Solution Set $\ (x_1,x_2,x_3)$ = $[\frac{3}{x-2}, t,4]^T$, $\ \forall t \in R$,$\ $ infinit solution</b>
# </p>
# </font></p>

# %% [markdown]
# **<p style="line-height: 1.5">
# <font size = 4px face = "Times New Roman">2. Let $K = \begin{bmatrix}2&a&1\\0&1&1/a\\1&1&0\end{bmatrix}$ for some $a \ne 0$. Use row reduction to find $K^{−1}$, showing all details of your row operations.</font></p>**

# %% [markdown]
# <p style="line-height: 2">
# <font size = 2px face = "Times New Roman">
# <i>
# Note: $E_{ij}(k)$ is the math symbol refers to Elememtary Row Transformation.
#
# $E_{ij}$: Exchange two rows.<br>
# $E_i(k)$: Let row $i$ times $k$.<br>
# $E_{ij}(k)$: Let $k$ times row $j$ add to row $i$.
# </i>

# %% [markdown]
# <font size = 4px face = "Times New Roman">
# <p style="line-height: 2">
# <i>Answer:</i><br>
# </p><p style="line-height: 6">
# $[K｜I] = \left[
# \begin{array}{ccc|ccc}
#   2&a&1&1&0&0 \\
#   0&1&\frac{1}{a}&0&1&0\\
#   1&1&0&0&0&1
# \end{array}
# \right]$
#  $\ \xrightarrow{E_{13}}\ $
# $\left[
# \begin{array}{ccc|ccc}
#   1&1&0&0&0&1\\
#   0&1&\frac{1}{a}&0&1&0\\
#   2&a&1&1&0&0
# \end{array}
# \right]$
#  $\ \xrightarrow{E_{31}(-2)}\ $
# $\left[
# \begin{array}{ccc|ccc}
#   1&1&0&0&0&1\\
#   0&1&\frac{1}{a}&0&1&0\\
#   0&a-2&1&1&0&-2
# \end{array}
# \right]$<br>
#  $\ \xrightarrow{E_{32}(2-a)}\ $
# $\left[
# \begin{array}{ccc|ccc}
#   1&1&0&0&0&1\\
#   0&1&\frac{1}{a}&0&1&0\\
#   0&0&\frac{2}{a}&1&2-a&-2
# \end{array}
# \right]$
#  $\ \xrightarrow{E_{23}(-1/2)}\ $
# $\left[
# \begin{array}{ccc|ccc}
#   1&1&0&0&0&1\\
#   0&1&0&-\frac{1}{2}&\frac{a}{2}&1\\
#   0&0&\frac{2}{a}&1&2-a&-2
# \end{array}
# \right]$<br>
# $\ \xrightarrow{E_{12}(-1)}\ $
# $\left[
# \begin{array}{ccc|ccc}
#   1&0&0&\frac{1}{2}&-\frac{a}{2}&0\\
#   0&1&0&-\frac{1}{2}&\frac{a}{2}&1\\
#   0&0&\frac{2}{a}&1&2-a&-2
# \end{array}
# \right]$ $\ \xrightarrow{E_{3}(a/2)}\ $
# $\left[
# \begin{array}{ccc|ccc}
#   1&0&0&\frac{1}{2}&-\frac{a}{2}&0\\
#   0&1&0&-\frac{1}{2}&\frac{a}{2}&1\\
#   0&0&1&\frac{a}{2}& -\frac{a^2}{2} +a &-a
# \end{array}
# \right] = [I | K^{-1}]$ <br>
# Thus, $K^{-1} =\begin{bmatrix}\frac{1}{2}&-\frac{a}{2}&0\\-\frac{1}{2}&\frac{a}{2}&1\\\frac{a}{2}& -\frac{a^2}{2} +a &-a\end{bmatrix}$
# <br>
# </p></font>

# %% [markdown]
# **<p style="line-height: 1.5">
# <font size = 4px face = "Times New Roman">3. Consider the vectors
# <br>
#     $$v_1 = \begin{bmatrix}1\\0\\2\end{bmatrix},\ v_2 = \begin{bmatrix}1\\1\\0\end{bmatrix},\  v_1 = \begin{bmatrix}-1\\3\\k\end{bmatrix}$$</font></p>**

# %% [markdown]
# **<p style="line-height: 1.5">
# <font size = 4px face = "Times New Roman">(a) By solving $c_1 v_1 + c_2 v_2 + c_3 v_3 = 0$, determine the unique value k for which $\{ v_1 , v_2 , v_3 \}$ is a linearly dependent set.</font></p>**

# %% [markdown]
# <font size = 4px face = "Times New Roman">
# <p style="line-height: 2">
# <i>Answer:</i><br>
# We can use<b> Row Echelon Form(REF) </b>to determine the <b>Rank</b> of $[v_1,v_2,v_3] < 3$, that make $v_1,v_2,v_3$ are linearly dependent.<br>
#
# $[v_1,v_2,v_3] =
# \begin{bmatrix}
# 1&1&-1\\
# 0&1&3\\
# 2&0&k\end{bmatrix}$
# $\ \xrightarrow{E_{31}(-2)}\ $
# $\begin{bmatrix}
# 1&1&-1\\
# 0&1&3\\
# 0&-2&k+2\end{bmatrix}$
# $\ \xrightarrow{E_{32}(2)}\ $
# $\begin{bmatrix}
# 1&1&-1\\
# 0&1&3\\
# 0&0&k+8\end{bmatrix}$
#
# <p style="line-height: 2">
# We don't need to use<b> Elementary Row Operations </b>to make the matrix into the<b> RREF</b>, just making<b> REF </b>like this is enough to determine the <b>Rank</b> of this matrix.
# </p>
# <p style="line-height: 2">
# So we can draw the conclusion that when $k = -8$, the<b> Rank </b>of this matrix must $\lt 3$, which makes $\{v_1,v_2,v_3\}$
# is a linearly dependent set.
# </p></font>

# %% [markdown]
# **<p style="line-height: 1.5">
# <font size = 4px face = "Times New Roman">(b) For the value of $k$ above, write one of the vectors as a linear combination of the others.</font></p>**

# %% [markdown]
# <font size = 4px face = "Times New Roman">
# <p style="line-height: 2">
# <i>Answer:</i><br>
# From 3(a) we know that:<br>
# </p>
# <p style="line-height: 2">
# $\{v_1,v_2,v_3\} = \{\
# \begin{bmatrix}
# 1\\
# 0\\
# 2\end{bmatrix},
# \begin{bmatrix}
# 1\\
# 1\\
# 0\end{bmatrix},
# \begin{bmatrix}
# -1\\
# 3\\
# -8\end{bmatrix}\ \}$
# </p>
# <p style="line-height: 2">
# We know that $v_3 = k_1·v_1 + k_2·v_2$,$\ $ because $v_i\ (\ \forall i \in \{1,2,3\}\ )$ can be represented by the linear combination of the other vectors $v_j$ and $v_k$ $(\ j,k \in \{1,2,3\}$, and $i \ne j \ne k\ )$
# </p>
# <p style="line-height: 2">
# So we have $\begin{bmatrix}
# -1\\
# 3\\
# -8\end{bmatrix} =
# \begin{bmatrix}
# k_1\\
# 0\\
# 2k_1\end{bmatrix}
# +
# \begin{bmatrix}
# k_2\\
# k_2\\
# 0\end{bmatrix} =
# \begin{bmatrix}
# k_1 + k_2\\
# k_2\\
# 2k_1\end{bmatrix}
# $
# <br>
# </p>
# <p style="line-height: 2">
# $
# 2k_1 = -8,\
# k_2 = 3,\
# k_1 + k_2 = -1
# $<br>
# So we have $k_1 = -4,\ k_2 = 3$,$\ $ that make $v_3 =-4v_1 + 3v_2$
# </p></font>

# %% [markdown]
# **<p style="line-height: 1.5">
# <font size = 4px face = "Times New Roman">4. Find the eigenvalues and eigenspaces of $A = \begin{bmatrix}8&2\\-2&3\end{bmatrix}$, showing all working. </font></p>**

# %% [markdown]
# <font size = 4px face = "Times New Roman">
# <p style="line-height: 2">
# <i>Answer:</i><br>
# We can solve this equation $|\lambda I - A | =0$ to find the <b>eigenvalues</b> $\lambda_i$ of A
#
# $|\lambda I - A | =\det \begin{bmatrix}
# \lambda - 8&-2\\
# 2&\lambda-3\end{bmatrix} = 0$
#
# $(\lambda-8)(\lambda - 3) +4 = \lambda^2 - 11\lambda +28 = (\lambda-4)(\lambda-7)= 0$
#
# So <b>eigenvalues</b> of A are $\ \lambda_1 = 4$ and  $\lambda_2 =  7$
#
#
# when $\lambda = 4$, $[\lambda I - A ]= \begin{bmatrix}-4&-2\\2&1\end{bmatrix} $ $\ \xrightarrow{E_{12}(2)}\ $
#     $\begin{bmatrix}0&0\\2&1\end{bmatrix}$, so $\ 2x_1 +x_2 = 0$, <b>eigenvector</b> $\ v_1 = (x_1,x_2) = [t,-2t]^T, t \in R$
#
# when $\lambda = 7$, $[\lambda I - A ]= \begin{bmatrix}-1&-2\\2&4\end{bmatrix} $ $\ \xrightarrow{E_{21}(2)}\ $
# $\begin{bmatrix}-1&-2\\0&0\end{bmatrix}$, so $\ -x_1 - 2x_2 = 0$, <b>eigenvector</b> $\ v_2 = (x_1,x_2) = [2t,-t]^T, t \in R$
# </p>
# <p style="line-height: 2">
# In summary, the <b>eigenvalues</b> $\lambda = 4$ correspondes to the <b>eigenspace</b> $E_4 = \{\begin{bmatrix}1\\-2\end{bmatrix}t |t \in R\}\ $, and the <b>eigenvalues</b> $\lambda = 7$ correspondes to the <b>eigenspace</b> $E_7 = \{\begin{bmatrix}2\\-1\end{bmatrix}t |t \in R\}\ $
#
# </p>
# </font>
